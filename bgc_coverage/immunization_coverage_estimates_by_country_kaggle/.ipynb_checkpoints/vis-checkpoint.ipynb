# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
bcg_df = pd.read_csv('BCG.csv')

# %%
bcg_df.head()
# Out:
#        Country   2018   2017   2016   2015   2014   2013   2012   2011   2010  \
# 0  Afghanistan   78.0   78.0   78.0   76.0   74.0   72.0   78.0   71.0   68.0
# 1      Albania   99.0   99.0   99.0   99.0   99.0   99.0   96.0   97.0   99.0
# 2      Algeria   99.0   99.0   99.0   99.0   99.0   99.0   99.0   99.0   99.0
# 3       Angola   86.0   83.0   49.0   69.0   72.0   71.0   73.0   74.0   79.0
# 4    Argentina   93.0   95.0   92.0   96.0   99.0   99.0   99.0   99.0   99.0
#
#    ...   1989   1988   1987   1986   1985   1984   1983   1982   1981   1980
# 0  ...   38.0   40.0   27.0   18.0   17.0   11.0   10.0   10.0    NaN    NaN
# 1  ...   94.0   92.0   92.0   92.0   92.0   90.0   90.0   92.0   93.0   93.0
# 2  ...   96.0   96.0   93.0   88.0   86.0    NaN    NaN    NaN    NaN    NaN
# 3  ...   47.0   32.0   29.0   32.0   28.0   28.0   25.0    NaN    NaN    NaN
# 4  ...   92.0   91.0   94.0   99.0   90.0   78.0   70.0   77.0   70.0   62.0
#
# [5 rows x 40 columns]

# %%
bcg_df.describe()
# Out:
#              2018        2017        2016        2015        2014        2013  \
# count  156.000000  156.000000  157.000000  158.000000  158.000000  158.000000
# mean    90.737179   90.961538   90.331210   90.006329   90.841772   91.132911
# std     11.706140   11.469390   13.308176   13.852037   12.739688   12.756966
# min     26.000000   25.000000   18.000000   24.000000   26.000000   27.000000
# 25%     88.750000   89.000000   88.000000   86.250000   89.000000   90.000000
# 50%     95.000000   95.000000   96.000000   96.000000   96.000000   96.000000
# 75%     98.000000   98.000000   98.000000   99.000000   99.000000   99.000000
# max     99.000000   99.000000   99.000000   99.000000   99.000000   99.000000
#
#              2012        2011        2010        2009  ...        1989  \
# count  159.000000  159.000000  158.000000  159.000000  ...  134.000000
# mean    91.949686   91.522013   91.645570   91.213836  ...   81.074627
# ...

# %%
major_countries = bcg_df.loc[bcg_df['Country'].isin(['Japan', 'Brazil', 'Russian Federation', 'China'])]
# major_countries.T.astype(float)
major_countries.T
# major_countries.T.index
# major_countries.T.plot(kind='bar')
# Out:
#             16     27     72                  122
# Country  Brazil  China  Japan  Russian Federation
#  2018        90     99     99                  95
#  2017        90     99     93                  95
#  2016        90     99     98                  96
#  2015        99     99     84                  96
#  2014        99     99     93                  96
#  2013        99     99     93                  96
#  2012        99     99     95                  96
#  2011        99     99     94                  95
#  2010        99     99     99                  96
#  2009        99     99     94                  96
#  2008        99     97     90                  96
#  2007        99     94     94                  97
#  2006        99     92    NaN                  97
#  2005        99     86    NaN                  97
#  2004        99     86    NaN                  96
#  2003        99     85    NaN                  97
#  2002        99     85    NaN                  97
# ...

# %%
single_country = bcg_df.loc[bcg_df['Country'] == 'China']

# %%
single_country
# Out:
#    Country   2018   2017   2016   2015   2014   2013   2012   2011   2010  \
# 27   China   99.0   99.0   99.0   99.0   99.0   99.0   99.0   99.0   99.0
#
#     ...   1989   1988   1987   1986   1985   1984   1983   1982   1981   1980
# 27  ...   98.0   98.0   85.0   70.0   64.0   59.0   34.0    NaN    NaN    NaN
#
# [1 rows x 40 columns]
